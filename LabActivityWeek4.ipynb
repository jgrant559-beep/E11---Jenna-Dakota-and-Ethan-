# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("lab4.csv")
nbins = np.max(data.iloc[:, 1])


plt.hist(data.iloc[:, 1], color="#52ff5b", edgecolor="k", alpha=0.75)
plt.xlabel("Particles > 0.3um / 0.1L air")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# I noticed that the particle counts are pretty evenly distributed.
